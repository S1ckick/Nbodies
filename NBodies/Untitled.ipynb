# %%
import matplotlib.pyplot as plt
import numpy as np

import json
with open('log.json') as f:
  data_energy = json.load(f)
figure, axes = plt.subplots(figsize = (20,20))

axes.plot(list(map(float, data_energy)),linestyle='solid', marker='o', markersize=4, label='dE/E0')
axes.set_xlabel('n computes')
axes.set_ylabel('|E-E0|/E0')
axes.legend()

font = { 'size' : 40}

plt.rc('font', **font)

# %%
import matplotlib.pyplot as plt
import numpy as np


import json
with open('moment.json') as f:
  data_moment = json.load(f)

figure, axes = plt.subplots(figsize = (20,20))


axes.plot(list(map(float, data_moment)),linestyle='solid', marker='o', markersize=4, label='|L-L0|/L0')

axes.set_xlabel('n computes')
axes.set_ylabel('|L-L0|/L0')
axes.legend(prop={'size': 20})

# %%
import matplotlib.pyplot as plt
import numpy as np


import json
with open('center.json') as f:
  data_center = json.load(f)

figure, axes = plt.subplots(figsize = (20,20))

axes.plot(list(map(float, data_center)),linestyle='solid', marker='o', markersize=4, label='|X-X0|')

axes.set_xlabel('n computes')
axes.set_ylabel('|X-X0|')
axes.legend()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from math import sqrt
from mpl_toolkits.mplot3d import axes3d
import numpy as np
import json
pos_x = []
pos_y = []
pos_z = []
vel_x = []
vel_y = []
vel_z = []

with open('../res_out.txt') as f:
    data = f.readlines()
    for line in data:
        if line:
            numbers = line.split()
            for i in range(16):
                pos_x.append(numbers[0 + 6*i])
                pos_y.append(numbers[1 + 6*i])
                pos_z.append(numbers[2 + 6*i])
                vel_x.append(numbers[3 + 6*i])
                vel_y.append(numbers[4 + 6*i])
                vel_z.append(numbers[5 + 6*i])
plt.rcParams["figure.figsize"] = (30,20)                
fig = plt.figure()
ax = fig.add_subplot(1,1,1, projection='3d')

for i in range(16):
    x_body_coords = pos_x[i : : 16]
    y_body_coords = pos_y[i : : 16]
    z_body_coords = pos_z[i : : 16]
    ax.plot(list(map(float, x_body_coords)),list(map(float, y_body_coords)),list(map(float, z_body_coords)))

plt.savefig('anime2.png', dpi=300)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_83465/3352170109.py in <module>
#      12 vel_z = []
#      13
# ---> 14 with open('../res_out.txt') as f:
#      15     data = f.readlines()
#      16     for line in data:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../res_out.txt'

# %%
coords = data_bodies["coords"]
iters = data_bodies["iter"]
bodies = data_bodies["num"]
plt.rcParams["figure.figsize"] = (30,20)
fig = plt.figure()
ax = fig.add_subplot(1,1,1, projection='3d')
print(bodies)
#coords = np.reshape(data_bodies["coords"], (data_bodies["iter"], data_bodies["num"], 3))
#print(coords)
colors = ['	black','silver',]
for i in range(bodies):
    x_body_coords = coords[i * 3 + 0 : : bodies * 3]
    y_body_coords = coords[i * 3 + 1 : : bodies * 3]
    z_body_coords = coords[i * 3 + 2 : : bodies * 3]
    ax.plot(list(map(float, x_body_coords)),list(map(float, y_body_coords)),list(map(float, z_body_coords)))

    #axes.plot([i for i in range(len(sq_vec))],list(map(float, sq_vec)),linestyle='solid', marker='o', markersize=4, label='|X-X0|')  
#ax.set_xlabel('X axis')
#ax.set_ylabel('Y axis')
#ax.set_zlabel('Z axis')

plt.savefig('anime2.png', dpi=300)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from math import sqrt
from mpl_toolkits.mplot3d import axes3d
import numpy as np
import json
pos_x = []
pos_y = []
pos_z = []
vel_x = []
vel_y = []
vel_z = []

energy = []
impulse = []
center = []
with open('../build/res_out.txt') as f:
    data = f.readlines()
    for line in data:
        if line:
            numbers = line.split()
            for i in range(16):
                pos_x.append(numbers[0 + 6*i])
                pos_y.append(numbers[1 + 6*i])
                pos_z.append(numbers[2 + 6*i])
                vel_x.append(numbers[3 + 6*i])
                vel_y.append(numbers[4 + 6*i])
                vel_z.append(numbers[5 + 6*i])
            energy.append(numbers[-3])
            impulse.append(numbers[-2])
            center.append(numbers[-1])
plt.rcParams["figure.figsize"] = (30,20)                
fig = plt.figure()
ax = fig.add_subplot(1,1,1, projection='3d')

for i in range(16):
    x_body_coords = pos_x[i : : 16]
    y_body_coords = pos_y[i : : 16]
    z_body_coords = pos_z[i : : 16]
    ax.plot(list(map(float, x_body_coords)),list(map(float, y_body_coords)),list(map(float, z_body_coords)))

plt.savefig('anime2.png', dpi=300)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_6320/337798158.py in <module>
#      21             numbers = line.split()
#      22             for i in range(16):
# ---> 23                 pos_x.append(numbers[0 + 6*i])
#      24                 pos_y.append(numbers[1 + 6*i])
#      25                 pos_z.append(numbers[2 + 6*i])
#
# IndexError: list index out of range

# %%
print(energy)
# Out:
# ['-1.989633282489303623850938625606e-03', '-1.988886932821126959000029976065e-03', '-1.988140593925219511086364752151e-03', '-1.987394265801556978077008227827e-03', '-1.986647948450114861951339172678e-03', '-1.985901641870868468805010011908e-03', '-1.985155346063792908953875647224e-03', '-1.984409061028863097037890952559e-03', '-1.983662786766053752124976958592e-03', '-1.982916523275339397814855740024e-03', '-1.982170270556694362342854019608e-03', '-1.981424028610092778683675502951e-03', '-1.980677797435508584655141958096e-03', '-1.979931577032915523021903053932e-03', '-1.979185367402287141599114971492e-03', '-1.978439168543596793356087802214e-03', '-1.977692980456817636519901747249e-03', '-1.976946803141922634678992131930e-03', '-1.976200636598884556886703249520e-03', '-1.975454480827675977764811048375e-03', '-1.974708335828269277607014676687e-03', '-1.973962201600636642482396898963e-03', '-1.973216078144750064338853398430e-03', '-1.972469965460581341106490979567e-03', '-1.971723863
# ...

# %%
figure, axes = plt.subplots(figsize = (20,20))

axes.plot(list(map(float, energy)),linestyle='solid', marker='o', markersize=4, label='|X-X0|')

# %%
figure, axes = plt.subplots(figsize = (20,20))

axes.plot(list(map(float, impulse)),linestyle='solid', marker='o', markersize=4, label='|X-X0|')

# %%
figure, axes = plt.subplots(figsize = (20,20))

axes.plot(list(map(float, center)),linestyle='solid', marker='o', markersize=4, label='|X-X0|')

# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from math import sqrt
from mpl_toolkits.mplot3d import axes3d
import numpy as np
import json
pos_b_x = []
pos_b_y = []
pos_b_z = []
vel_x = []
vel_y = []
vel_z = []

energy = []
impulse = []
center = []
with open('../build/res_b_out.txt') as f:
    data = f.readlines()
    for line in data:
        if line:
            numbers = line.split()
            for i in range(16):
                pos_b_x.append(numbers[0 + 6*i])
                pos_b_y.append(numbers[1 + 6*i])
                pos_b_z.append(numbers[2 + 6*i])
                vel_x.append(numbers[3 + 6*i])
                vel_y.append(numbers[4 + 6*i])
                vel_z.append(numbers[5 + 6*i])
            energy.append(numbers[-3])
            impulse.append(numbers[-2])
            center.append(numbers[-1])
plt.rcParams["figure.figsize"] = (30,20)                
fig = plt.figure()
ax = fig.add_subplot(1,1,1, projection='3d')

for i in range(16):
    x_body_coords = pos_b_x[i : : 16]
    y_body_coords = pos_b_y[i : : 16]
    z_body_coords = pos_b_z[i : : 16]
    ax.plot(list(map(float, x_body_coords)),list(map(float, y_body_coords)),list(map(float, z_body_coords)))

plt.savefig('anime2.png', dpi=300)

# %%
pos_x = pos_x[::16]
pos_b_x = pos_b_x[::16]

# %%
pos_b_x.reverse()

# %%
print(pos_b_x[0], pos_x[0])
# Out:
# 5.2031999596384231e-04 5.2031999596384231e-04

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 22})
from mpl_toolkits import mplot3d
from math import sqrt
from mpl_toolkits.mplot3d import axes3d
import numpy as np
diff = []


with open('build/Mars_diff.txt') as f:
    data = f.readlines()
    for line in data:
        if line:
            diff.append(line[1:-1])
    
figure, axes = plt.subplots(figsize = (20,20))

axes.plot(list(map(float, diff)),linestyle='solid', marker='o', markersize=4, label='|X-X0|')
plt.savefig('dd_150_notay.png')

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 22})
from mpl_toolkits import mplot3d
from math import sqrt
from mpl_toolkits.mplot3d import axes3d
import numpy as np
diff = []


with open('build/res_inv.txt') as f:
    data = f.readlines()
    for line in data:
        if line:
            diff.append(line[1:-1])
    
figure, axes = plt.subplots(figsize = (20,20))
print(len(diff))
xs = [i*100 for i in range(len(diff))]
axes.plot(xs, list(map(float, diff)),  marker='o', markersize=4)
# Out:
# 467201

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 22})
from mpl_toolkits import mplot3d
from math import sqrt
from mpl_toolkits.mplot3d import axes3d
import numpy as np
diff = []


tay = open("build/taylor8.txt", 'r')
data_tay = tay.readlines()
tay.close()

notay = open("build/no_taylor.txt", 'r')
data_notay = notay.readlines()
notay.close()

for i in range(len(data_notay)):
    tay_list = [float(item) for item in data_tay[i].split()]
    notay_list = [float(item) for item in data_notay[i].split()]
    diff.append(np.sqrt(np.power(tay_list[0] - notay_list[0], 2) +
                        np.power(tay_list[1] - notay_list[1], 2) + 
                        np.power(tay_list[2] - notay_list[2], 2)))
    
figure, axes = plt.subplots(figsize = (20,20))
xs = [i for i in range(len(diff))]
axes.plot(xs, list(map(float, diff)),  marker='o', markersize=4)

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 22})
from mpl_toolkits import mplot3d
from math import sqrt
from mpl_toolkits.mplot3d import axes3d
import numpy as np
diff = []


tay = open("build/taylor.txt", 'r')
data_tay = tay.readlines()
tay.close()

notay = open("build/no_taylor.txt", 'r')
data_notay = notay.readlines()
notay.close()

for i in range(len(data_notay)):
    tay_list = [float(item) for item in data_tay[i].split()]
    notay_list = [float(item) for item in data_notay[i].split()]
    diff.append(np.sqrt(np.power(tay_list[0] - notay_list[0], 2) +
                        np.power(tay_list[1] - notay_list[1], 2) + 
                        np.power(tay_list[2] - notay_list[2], 2)))
    
figure, axes = plt.subplots(figsize = (20,20))
xs = [i for i in range(len(diff))]
axes.plot(xs, list(map(float, diff)),  marker='o', markersize=4)
