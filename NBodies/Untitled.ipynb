# %%
import matplotlib.pyplot as plt
import numpy as np


import json
with open('log.json') as f:
  data_energy = json.load(f)

figure, axes = plt.subplots(figsize = (20,20))

axes.plot(data_energy["n"],data_energy["energy"],linestyle='solid', marker='o', markersize=4, label='Energy')

axes.set_xlabel('n computes')
axes.set_ylabel('energy')
axes.legend(prop={'size': 15})

# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import axes3d
import numpy as np

import json
with open('bodies.json') as f:
  data_bodies = json.load(f)

#fig = plt.figure()

#max_range = max(max(x_1),max(y_1),max(z_1),max(x_2),max(y_2),max(z_2))


#fig, ax = plt.subplots(2,2) #fig.add_subplot(1,1,1, projection='3d')
#fig.tight_layout()
#ax[0,0].plot(x_2,y_2, label="sat")
#ax[0,1].plot(x_2,z_2, label="sat")
#ax[1,0].plot(y_2,z_2, label="sat")

#ax[0,0].plot(x_1,y_1, label="sun")
#ax[0,1].plot(x_1,z_1, label="sun")
#ax[1,0].plot(y_1,z_1, label="sun")

#ax[0,0].set_xlabel('X')
#ax[0,0].set_ylabel('Y')

#ax[0,1].set_xlabel('X')
#ax[0,1].set_ylabel('Z')

#ax[1,0].set_xlabel('Y')
#ax[1,0].set_ylabel('Z')

#ax.plot(x_1, y_1, z_1, label="sun")
#ax.plot(x_2, y_2, z_2, label="satelite")


#plt.show()

fig = plt.figure()
ax = fig.add_subplot(1,1,1, projection='3d')

for item in data_bodies:
    ax.plot(item["X"], item["Y"], item["Z"], label="planet")

#ax.set_xlim([-max_range,max_range])    
#ax.set_ylim([-max_range,max_range])
#ax.set_zlim([-max_range,max_range])
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')

ax.legend()
plt.show()
# Out:
# /Users/maksim/opt/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
