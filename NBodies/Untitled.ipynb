# %%
import matplotlib.pyplot as plt
import numpy as np

import json
with open('log.json') as f:
  data_energy = json.load(f)
figure, axes = plt.subplots(figsize = (20,20))

axes.plot(list(map(float, data_energy)),linestyle='solid', marker='o', markersize=4, label='dE/E0')
axes.set_xlabel('n computes')
axes.set_ylabel('|E-E0|/E0')
axes.legend()

font = { 'size' : 40}

plt.rc('font', **font)

# %%
import matplotlib.pyplot as plt
import numpy as np


import json
with open('moment.json') as f:
  data_moment = json.load(f)

figure, axes = plt.subplots(figsize = (20,20))


axes.plot(list(map(float, data_moment)),linestyle='solid', marker='o', markersize=4, label='|L-L0|/L0')

axes.set_xlabel('n computes')
axes.set_ylabel('|L-L0|/L0')
axes.legend(prop={'size': 20})

# %%
import matplotlib.pyplot as plt
import numpy as np


import json
with open('center.json') as f:
  data_center = json.load(f)

figure, axes = plt.subplots(figsize = (20,20))

axes.plot(list(map(float, data_center)),linestyle='solid', marker='o', markersize=4, label='|X-X0|')

axes.set_xlabel('n computes')
axes.set_ylabel('|X-X0|')
axes.legend()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from math import sqrt
from mpl_toolkits.mplot3d import axes3d
import numpy as np
import json
pos_x = []
pos_y = []
pos_z = []
vel_x = []
vel_y = []
vel_z = []

with open('../res_out.txt') as f:
    data = f.readlines()
    for line in data:
        if line:
            numbers = line.split()
            for i in range(16):
                pos_x.append(numbers[0 + 6*i])
                pos_y.append(numbers[1 + 6*i])
                pos_z.append(numbers[2 + 6*i])
                vel_x.append(numbers[3 + 6*i])
                vel_y.append(numbers[4 + 6*i])
                vel_z.append(numbers[5 + 6*i])
plt.rcParams["figure.figsize"] = (30,20)                
fig = plt.figure()
ax = fig.add_subplot(1,1,1, projection='3d')

for i in range(16):
    x_body_coords = pos_x[i : : 16]
    y_body_coords = pos_y[i : : 16]
    z_body_coords = pos_z[i : : 16]
    ax.plot(list(map(float, x_body_coords)),list(map(float, y_body_coords)),list(map(float, z_body_coords)))

plt.savefig('anime2.png', dpi=300)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_83465/3352170109.py in <module>
#      12 vel_z = []
#      13
# ---> 14 with open('../res_out.txt') as f:
#      15     data = f.readlines()
#      16     for line in data:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../res_out.txt'

# %%
coords = data_bodies["coords"]
iters = data_bodies["iter"]
bodies = data_bodies["num"]
plt.rcParams["figure.figsize"] = (30,20)
fig = plt.figure()
ax = fig.add_subplot(1,1,1, projection='3d')
print(bodies)
#coords = np.reshape(data_bodies["coords"], (data_bodies["iter"], data_bodies["num"], 3))
#print(coords)
colors = ['	black','silver',]
for i in range(bodies):
    x_body_coords = coords[i * 3 + 0 : : bodies * 3]
    y_body_coords = coords[i * 3 + 1 : : bodies * 3]
    z_body_coords = coords[i * 3 + 2 : : bodies * 3]
    ax.plot(list(map(float, x_body_coords)),list(map(float, y_body_coords)),list(map(float, z_body_coords)))

    #axes.plot([i for i in range(len(sq_vec))],list(map(float, sq_vec)),linestyle='solid', marker='o', markersize=4, label='|X-X0|')  
#ax.set_xlabel('X axis')
#ax.set_ylabel('Y axis')
#ax.set_zlabel('Z axis')

plt.savefig('anime2.png', dpi=300)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from math import sqrt
from mpl_toolkits.mplot3d import axes3d
import numpy as np
import json
pos_x = []
pos_y = []
pos_z = []
vel_x = []
vel_y = []
vel_z = []

energy = []
impulse = []
center = []
with open('../build/res_out.txt') as f:
    data = f.readlines()
    for line in data:
        if line:
            numbers = line.split()
            for i in range(16):
                pos_x.append(numbers[0 + 6*i])
                pos_y.append(numbers[1 + 6*i])
                pos_z.append(numbers[2 + 6*i])
                vel_x.append(numbers[3 + 6*i])
                vel_y.append(numbers[4 + 6*i])
                vel_z.append(numbers[5 + 6*i])
            energy.append(numbers[-3])
            impulse.append(numbers[-2])
            center.append(numbers[-1])
plt.rcParams["figure.figsize"] = (30,20)                
fig = plt.figure()
ax = fig.add_subplot(1,1,1, projection='3d')

for i in range(16):
    x_body_coords = pos_x[i : : 16]
    y_body_coords = pos_y[i : : 16]
    z_body_coords = pos_z[i : : 16]
    ax.plot(list(map(float, x_body_coords)),list(map(float, y_body_coords)),list(map(float, z_body_coords)))

plt.savefig('anime2.png', dpi=300)

# %%
print(energy)
# Out:
# ['0.0000000000000000e+00', '1.3145588335652792e-15', '2.1361581045435788e-15', '4.9295956258697971e-16', '2.1361581045435788e-15', '1.9718382503479188e-15', '3.6150367923045178e-15', '1.4788786877609391e-15', '2.4647978129348984e-15', '2.4647978129348984e-15', '1.8075183961522589e-15', '3.9436765006958377e-15', '3.7793566465001773e-15', '2.1361581045435788e-15', '4.2723162090871576e-15', '2.4647978129348984e-15', '3.2863970839131978e-15', '3.2863970839131978e-15', '3.1220772297175378e-15', '2.6291176671305583e-15', '2.9577573755218783e-15', '1.4788786877609391e-15', '3.1220772297175378e-15', '3.2863970839131978e-15', '2.4647978129348984e-15', '2.6291176671305583e-15', '3.2863970839131978e-15', '4.9295956258697967e-15', '2.7934375213262183e-15', '3.1220772297175378e-15', '3.4507169381088578e-15', '4.4366360632828172e-15', '5.4225551884567762e-15', '2.6291176671305583e-15', '4.7652757716741371e-15', '2.7934375213262183e-15', '3.4507169381088578e-15', '3.1220772297175378e-15', '3.1220772297175378e-15', '3.1220772297175378e-15', '3.6150367923045178e-15', '3.4507169381088578e-15', '4.1079963548914973e-15', '5.0939154800654571e-15', '5.0939154800654571e-15', '3.1220772297175378e-15', '2.9577573755218783e-15', '2.9577573755218783e-15', '3.4507169381088578e-15', '4.6009559174784768e-15', '4.6009559174784768e-15', '5.4225551884567762e-15', '3.2863970839131978e-15', '4.9295956258697967e-15', '2.9577573755218783e-15', '3.4507169381088578e-15', '1.6431985419565990e-16', '3.6150367923045178e-15', '2.1361581045435788e-15', '4.6009559174784768e-15', '1.9718382503479188e-15', '3.9436765006958377e-15', '2.6291176671305583e-15', '4.6009559174784768e-15', '3.6150367923045178e-15', '3.1220772297175378e-15', '2.3004779587392384e-15', '3.4507169381088578e-15', '3.2863970839131978e-15', '3.2863970839131978e-15', '4.6009559174784768e-15', '3.9436765006958377e-15', '4.2723162090871576e-15', '2.9577573755218783e-15', '3.1220772297175378e-15', '4.2723162090871576e-15', '3.6150367923045178e-15', '2.7934375213262183e-15', '4.4366360632828172e-15', '3.4507169381088578e-15', '4.2723162090871576e-15', '3.4507169381088578e-15', '3.2863970839131978e-15', '2.3004779587392384e-15', '4.9295956258697967e-15', '4.4366360632828172e-15', '4.2723162090871576e-15', '5.0939154800654571e-15', '4.2723162090871576e-15', '3.1220772297175378e-15', '3.1220772297175378e-15', '2.1361581045435788e-15', '2.7934375213262183e-15', '2.3004779587392384e-15', '3.7793566465001773e-15', '3.9436765006958377e-15', '3.9436765006958377e-15', '4.6009559174784768e-15', '3.1220772297175378e-15', '4.1079963548914973e-15', '4.4366360632828172e-15', '1.6431985419565989e-15', '4.6009559174784768e-15', '3.7793566465001773e-15', '4.4366360632828172e-15', '2.9577573755218783e-15', '2.7934375213262183e-15', '3.9436765006958377e-15', '3.9436765006958377e-15', '3.2863970839131978e-15', '3.9436765006958377e-15', '5.9155147510437565e-15', '4.6009559174784768e-15', '4.2723162090871576e-15', '5.0939154800654571e-15', '4.9295956258697967e-15', '6.0798346052394161e-15', '3.9436765006958377e-15', '4.4366360632828172e-15', '3.6150367923045178e-15', '3.4507169381088578e-15', '4.1079963548914973e-15', '2.9577573755218783e-15', '3.9436765006958377e-15', '2.9577573755218783e-15', '3.2863970839131978e-15', '3.9436765006958377e-15', '3.4507169381088578e-15', '3.1220772297175378e-15', '2.9577573755218783e-15', '3.9436765006958377e-15', '3.7793566465001773e-15', '5.9155147510437565e-15', '6.2441544594350757e-15', '3.6150367923045178e-15', '3.7793566465001773e-15', '3.1220772297175378e-15', '3.1220772297175378e-15', '4.4366360632828172e-15', '5.5868750426524366e-15', '4.9295956258697967e-15', '7.0657537304133751e-15', '4.7652757716741371e-15', '5.5868750426524366e-15', '3.7793566465001773e-15', '6.0798346052394161e-15', '5.0939154800654571e-15', '3.1220772297175378e-15', '5.4225551884567762e-15', '5.7511948968480962e-15', '4.9295956258697967e-15', '4.2723162090871576e-15', '3.9436765006958377e-15', '4.6009559174784768e- ...

# %%
figure, axes = plt.subplots(figsize = (20,20))

axes.plot(list(map(float, energy)),linestyle='solid', marker='o', markersize=4, label='|X-X0|')

# %%
figure, axes = plt.subplots(figsize = (20,20))

axes.plot(list(map(float, impulse)),linestyle='solid', marker='o', markersize=4, label='|X-X0|')

# %%
figure, axes = plt.subplots(figsize = (20,20))

axes.plot(list(map(float, center)),linestyle='solid', marker='o', markersize=4, label='|X-X0|')

# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from math import sqrt
from mpl_toolkits.mplot3d import axes3d
import numpy as np
import json
pos_b_x = []
pos_b_y = []
pos_b_z = []
vel_x = []
vel_y = []
vel_z = []

energy = []
impulse = []
center = []
with open('../build/res_b_out.txt') as f:
    data = f.readlines()
    for line in data:
        if line:
            numbers = line.split()
            for i in range(16):
                pos_b_x.append(numbers[0 + 6*i])
                pos_b_y.append(numbers[1 + 6*i])
                pos_b_z.append(numbers[2 + 6*i])
                vel_x.append(numbers[3 + 6*i])
                vel_y.append(numbers[4 + 6*i])
                vel_z.append(numbers[5 + 6*i])
            energy.append(numbers[-3])
            impulse.append(numbers[-2])
            center.append(numbers[-1])
plt.rcParams["figure.figsize"] = (30,20)                
fig = plt.figure()
ax = fig.add_subplot(1,1,1, projection='3d')

for i in range(16):
    x_body_coords = pos_b_x[i : : 16]
    y_body_coords = pos_b_y[i : : 16]
    z_body_coords = pos_b_z[i : : 16]
    ax.plot(list(map(float, x_body_coords)),list(map(float, y_body_coords)),list(map(float, z_body_coords)))

plt.savefig('anime2.png', dpi=300)

# %%
pos_x = pos_x[::16]
pos_b_x = pos_b_x[::16]

# %%
pos_b_x.reverse()

# %%
print(pos_b_x[0], pos_x[0])
# Out:
# 5.2031999596384231e-04 5.2031999596384231e-04
