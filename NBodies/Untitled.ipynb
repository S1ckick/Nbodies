# %%
import matplotlib.pyplot as plt
import numpy as np

import json
with open('log.json') as f:
  data_energy = json.load(f)
figure, axes = plt.subplots(figsize = (20,20))

axes.plot(list(map(float, data_energy)),linestyle='solid', marker='o', markersize=4, label='dE/E0')
axes.set_xlabel('n computes')
axes.set_ylabel('|E-E0|/E0')
axes.legend()

font = { 'size' : 40}

plt.rc('font', **font)

# %%
import matplotlib.pyplot as plt
import numpy as np


import json
with open('moment.json') as f:
  data_moment = json.load(f)

figure, axes = plt.subplots(figsize = (20,20))


axes.plot(list(map(float, data_moment)),linestyle='solid', marker='o', markersize=4, label='|L-L0|/L0')

axes.set_xlabel('n computes')
axes.set_ylabel('|L-L0|/L0')
axes.legend(prop={'size': 20})

# %%
import matplotlib.pyplot as plt
import numpy as np


import json
with open('../build/center.json') as f:
  data_center = json.load(f)

figure, axes = plt.subplots(figsize = (20,20))

axes.plot(list(map(float, data_center)),linestyle='solid', marker='o', markersize=4, label='|X-X0|')

axes.set_xlabel('n computes')
axes.set_ylabel('|X-X0|')
axes.legend()

# %%
# !conda install --yes -c conda-forge ipyvolume
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/maksim/psi4conda
#
#   added / updated specs:
#     - ipyvolume
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     appnope-0.1.2              |   py38h50d1736_1          10 KB  conda-forge
#     argon2-cffi-21.1.0         |   py38h96a0964_0          46 KB  conda-forge
#     async_generator-1.10       |             py_0          18 KB  conda-forge
#     backcall-0.2.0             |     pyh9f0ad1d_0          13 KB  conda-forge
#     backports-1.0              |             py_2           4 KB  conda-forge
#     backports.functools_lru_cache-1.6.4|     pyhd8ed1ab_0           9 KB  conda-forge
#     bleach-4.1.0               |     pyhd8ed1ab_0         121 KB  conda-forge
#     bqplot-0.12.31             |     pyhd8ed1ab_0         1.0 MB  conda-forge
#     cloudpickle-2.0.0          |     pyhd8ed1ab_0          24 KB  conda-forge
#     cytoolz-0.11.0             |   py38h96a0964_3         344 KB  conda-forge
#     dask-core-2021.10.0        |     pyhd8ed1ab_0         775 KB  conda-forge
#     decorator-5.1.0            |     pyhd8ed1ab_0          11 KB  conda-forge
#     defusedxml-0.7.1           |     pyhd8ed1ab_0          23 KB  conda-forge
#     entrypoints-0.3            |  pyhd8ed1ab_1003           8 KB  conda-forge
#     enum34-1.1.10              |   py38h32f6830_2           4 KB  conda-forge
#     fsspec-2021.10.1           |     pyhd8ed1ab_0          86 KB  conda-forge
#     imagecodecs-lite-2019.12.3 |   py38hc7193ba_3         171 KB  conda-forge
#     imageio-2.9.0              |             py_0         3.1 MB  conda-forge
#     ipydatawidgets-4.2.0       |     pyhd3deb0d_0         171 KB  conda-forge
#     ipykernel-5.5.5            |   py38h6c79ece_0         167 KB  conda-forge
#     ipython-7.28.0             |   py38h5fd9f69_0         1.1 MB  conda-forge
#     ipython_genutils-0.2.0     |             py_1          21 KB  conda-forge
#     ipyvolume-0.6.0a8          |     pyhd8ed1ab_0         1.2 MB  conda-forge
#     ipywebrtc-0.6.0            |     pyhd8ed1ab_0         187 KB  conda-forge
#     ipywidgets-7.6.5           |     pyhd8ed1ab_0         101 KB  conda-forge
#     jedi-0.18.0                |   py38h50d1736_2         933 KB  conda-forge
#     jinja2-3.0.2               |     pyhd8ed1ab_0          99 KB  conda-forge
#     jsonschema-4.1.2           |     pyhd8ed1ab_0          54 KB  conda-forge
#     jupyter_client-7.0.6       |     pyhd8ed1ab_0          87 KB  conda-forge
#     jupyter_core-4.8.1         |   py38h50d1736_0          78 KB  conda-forge
#     jupyterlab_pygments-0.1.2  |     pyh9f0ad1d_0           8 KB  conda-forge
#     jupyterlab_widgets-1.0.2   |     pyhd8ed1ab_0         130 KB  conda-forge
#     libsodium-1.0.18           |       hbcb3906_1         516 KB  conda-forge
#     locket-0.2.0               |             py_2           6 KB  conda-forge
#     markupsafe-2.0.1           |   py38h96a0964_0          21 KB  conda-forge
#     matplotlib-inline-0.1.3    |     pyhd8ed1ab_0          11 KB  conda-forge
#     mistune-0.8.4              |py38h96a0964_1004          54 KB  conda-forge
#     nbclient-0.5.4             |     pyhd8ed1ab_0          60 KB  conda-forge
#     nbconvert-6.2.0            |   py38h50d1736_0         534 KB  conda-forge
#     nbformat-5.1.3             |     pyhd8ed1ab_0          47 KB  conda-forge
#     nest-asyncio-1.5.1         |     pyhd8ed1ab_0           9 KB  conda-forge
#     notebook-6.4.5             |     pyha770c72_0         6.3 MB  conda-forge
#     pandoc-2.14.2              |       h0d85af4_0        15.4 MB  conda-forge
#     pandocfilters-1.5.0        |     pyhd8ed1ab_0          11 KB  conda-forge
#     parso-0.8.2                |     pyhd8ed1ab_0          68 KB  conda-forge
#     partd-1.2.0                |     pyhd8ed1ab_0          18 KB  conda-forge
#     pathlib-1.0.1              |   py38h50d1736_4           4 KB  conda-forge
#     pexpect-4.8.0              |     pyh9f0ad1d_2          47 KB  conda-forge
#     pickleshare-0.7.5          |          py_1003           9 KB  conda-forge
#     prometheus_client-0.11.0   |     pyhd8ed1ab_0          46 KB  conda-forge
#     prompt-toolkit-3.0.21      |     pyha770c72_0         248 KB  conda-forge
#     ptyprocess-0.7.0           |     pyhd3deb0d_0          16 KB  conda-forge
#     pygments-2.10.0            |     pyhd8ed1ab_0         760 KB  conda-forge
#     pyrsistent-0.17.3          |   py38h96a0964_2          88 KB  conda-forge
#     pythreejs-2.3.0            |     pyhd8ed1ab_0         2.6 MB  conda-forge
#     pywavelets-1.1.1           |   py38hbe852b5_3         4.3 MB  conda-forge
#     pyzmq-22.2.1               |   py38h23ab428_1         421 KB
#     scikit-image-0.17.2        |   py38h5fc983b_1        10.3 MB  conda-forge
#     send2trash-1.8.0           |     pyhd8ed1ab_0          17 KB  conda-forge
#     terminado-0.12.1           |   py38h50d1736_0          27 KB  conda-forge
#     testpath-0.5.0             |     pyhd8ed1ab_0          86 KB  conda-forge
#     tifffile-2019.7.26.2       |           py38_0         219 KB  conda-forge
#     toolz-0.11.1               |             py_0          46 KB  conda-forge
#     traitlets-5.1.0            |     pyhd8ed1ab_0          82 KB  conda-forge
#     traittypes-0.2.1           |     pyh9f0ad1d_2          10 KB  conda-forge
#     wcwidth-0.2.5              |     pyh9f0ad1d_2          33 KB  conda-forge
#     webencodings-0.5.1         |             py_1          12 KB  conda-forge
#     widgetsnbextension-3.5.1   |   py38h50d1736_4         1.8 MB  conda-forge
#     zeromq-4.3.4               |       h23ab428_0         289 KB
#     ------------------------------------------------------------
#                                            Total:        54.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   appnope            conda-forge/osx-64::appnope-0.1.2-py38h50d1736_1
#   argon2-cffi        conda-forge/osx-64::argon2-cffi-21.1.0-py38h96a0964_0
#   async_generator    conda-forge/noarch::async_generator-1.10-py_0
#   backcall           conda-forge/noarch::backcall-0.2.0-pyh9f0ad1d_0
#   backports          conda-forge/noarch::backports-1.0-py_2
#   backports.functoo~ conda-forge/noarch::backports.functools_lru_cache-1.6.4-pyhd8ed1ab_0
#   bleach             conda-forge/noarch::bleach-4.1.0-pyhd8ed1ab_0
#   bqplot             conda-forge/noarch::bqplot-0.12.31-pyhd8ed1ab_0
#   cloudpickle        conda-forge/noarch::cloudpickle-2.0.0-pyhd8ed1ab_0
#   cytoolz            conda-forge/osx-64::cytoolz-0.11.0-py38h96a0964_3
#   dask-core          conda-forge/noarch::dask-core-2021.10.0-pyhd8ed1ab_0
#   decorator          conda-forge/noarch::decorator-5.1.0-pyhd8ed1ab_0
#   defusedxml         conda-forge/noarch::defusedxml-0.7.1-pyhd8ed1ab_0
#   entrypoints        conda-forge/noarch::entrypoints-0.3-pyhd8ed1ab_1003
#   enum34             conda-forge/osx-64::enum34-1.1.10-py38h32f6830_2
#   fsspec             conda-forge/noarch::fsspec-2021.10.1-pyhd8ed1ab_0
#   imagecodecs-lite   conda-forge/osx-64::imagecodecs-lite-2019.12.3-py38hc7193ba_3
#   imageio            conda-forge/noarch::imageio-2.9.0-py_0
#   ipydatawidgets     conda-forge/noarch::ipydatawidgets-4.2.0-pyhd3deb0d_0
#   ipykernel          conda-forge/osx-64::ipykernel-5.5.5-py38h6c79ece_0
#   ipython            conda-forge/osx-64::ipython-7.28.0-py38h5fd9f69_0
#   ipython_genutils   conda-forge/noarch::ipython_genutils-0.2.0-py_1
#   ipyvolume          conda-forge/noarch::ipyvolume-0.6.0a8-pyhd8ed1ab_0
#   ipywebrtc          conda-forge/noarch::ipywebrtc-0.6.0-pyhd8ed1ab_0
#   ipywidgets         conda-forge/noarch::ipywidgets-7.6.5-pyhd8ed1ab_0
#   jedi               conda-forge/osx-64::jedi-0.18.0-py38h50d1736_2
#   jinja2             conda-forge/noarch::jinja2-3.0.2-pyhd8ed1ab_0
#   jsonschema         conda-forge/noarch::jsonschema-4.1.2-pyhd8ed1ab_0
#   jupyter_client     conda-forge/noarch::jupyter_client-7.0.6-pyhd8ed1ab_0
#   jupyter_core       conda-forge/osx-64::jupyter_core-4.8.1-py38h50d1736_0
#   jupyterlab_pygmen~ conda-forge/noarch::jupyterlab_pygments-0.1.2-pyh9f0ad1d_0
#   jupyterlab_widgets conda-forge/noarch::jupyterlab_widgets-1.0.2-pyhd8ed1ab_0
#   libsodium          conda-forge/osx-64::libsodium-1.0.18-hbcb3906_1
#   locket             conda-forge/noarch::locket-0.2.0-py_2
#   markupsafe         conda-forge/osx-64::markupsafe-2.0.1-py38h96a0964_0
#   matplotlib-inline  conda-forge/noarch::matplotlib-inline-0.1.3-pyhd8ed1ab_0
#   mistune            conda-forge/osx-64::mistune-0.8.4-py38h96a0964_1004
#   nbclient           conda-forge/noarch::nbclient-0.5.4-pyhd8ed1ab_0
#   nbconvert          conda-forge/osx-64::nbconvert-6.2.0-py38h50d1736_0
#   nbformat           conda-forge/noarch::nbformat-5.1.3-pyhd8ed1ab_0
#   nest-asyncio       conda-forge/noarch::nest-asyncio-1.5.1-pyhd8ed1ab_0
#   notebook           conda-forge/noarch::notebook-6.4.5-pyha770c72_0
#   pandoc             conda-forge/osx-64::pandoc-2.14.2-h0d85af4_0
#   pandocfilters      conda-forge/noarch::pandocfilters-1.5.0-pyhd8ed1ab_0
#   parso              conda-forge/noarch::parso-0.8.2-pyhd8ed1ab_0
#   partd              conda-forge/noarch::partd-1.2.0-pyhd8ed1ab_0
#   pathlib            conda-forge/osx-64::pathlib-1.0.1-py38h50d1736_4
#   pexpect            conda-forge/noarch::pexpect-4.8.0-pyh9f0ad1d_2
#   pickleshare        conda-forge/noarch::pickleshare-0.7.5-py_1003
#   prometheus_client  conda-forge/noarch::prometheus_client-0.11.0-pyhd8ed1ab_0
#   prompt-toolkit     conda-forge/noarch::prompt-toolkit-3.0.21-pyha770c72_0
#   ptyprocess         conda-forge/noarch::ptyprocess-0.7.0-pyhd3deb0d_0
#   pygments           conda-forge/noarch::pygments-2.10.0-pyhd8ed1ab_0
#   pyrsistent         conda-forge/osx-64::pyrsistent-0.17.3-py38h96a0964_2
#   pythreejs          conda-forge/noarch::pythreejs-2.3.0-pyhd8ed1ab_0
#   pywavelets         conda-forge/osx-64::pywavelets-1.1.1-py38hbe852b5_3
#   pyzmq              pkgs/main/osx-64::pyzmq-22.2.1-py38h23ab428_1
#   scikit-image       conda-forge/osx-64::scikit-image-0.17.2-py38h5fc983b_1
#   send2trash         conda-forge/noarch::send2trash-1.8.0-pyhd8ed1ab_0
#   terminado          conda-forge/osx-64::terminado-0.12.1-py38h50d1736_0
#   testpath           conda-forge/noarch::testpath-0.5.0-pyhd8ed1ab_0
#   tifffile           conda-forge/osx-64::tifffile-2019.7.26.2-py38_0
#   toolz              conda-forge/noarch::toolz-0.11.1-py_0
#   traitlets          conda-forge/noarch::traitlets-5.1.0-pyhd8ed1ab_0
#   traittypes         conda-forge/noarch::traittypes-0.2.1-pyh9f0ad1d_2
#   wcwidth            conda-forge/noarch::wcwidth-0.2.5-pyh9f0ad1d_2
#   webencodings       conda-forge/noarch::webencodings-0.5.1-py_1
#   widgetsnbextension conda-forge/osx-64::widgetsnbextension-3.5.1-py38h50d1736_4
#   zeromq             pkgs/main/osx-64::zeromq-4.3.4-h23ab428_0
#
#
#
# Downloading and Extracting Packages
# ptyprocess-0.7.0     | 16 KB     | ##################################### | 100%
# widgetsnbextension-3 | 1.8 MB    | ##################################### | 100%
# imageio-2.9.0        | 3.1 MB    | ##################################### | 100%
# matplotlib-inline-0. | 11 KB     | ##################################### | 100%
# ipywidgets-7.6.5     | 101 KB    | ##################################### | 100%
# backcall-0.2.0       | 13 KB     | ##################################### | 100%
# cloudpickle-2.0.0    | 24 KB     | ##################################### | 100%
# jedi-0.18.0          | 933 KB    | ##################################### | 100%
# pandoc-2.14.2        | 15.4 MB   | ##################################### | 100%
# traitlets-5.1.0      | 82 KB     | ##################################### | 100%
# backports.functools_ | 9 KB      | ##################################### | 100%
# fsspec-2021.10.1     | 86 KB     | ##################################### | 100%
# nbformat-5.1.3       | 47 KB     | ##################################### | 100%
# send2trash-1.8.0     | 17 KB     | ##################################### | 100%
# partd-1.2.0          | 18 KB     | ##################################### | 100%
# webencodings-0.5.1   | 12 KB     | ##################################### | 100%
# nest-asyncio-1.5.1   | 9 KB      | ##################################### | 100%
# tifffile-2019.7.26.2 | 219 KB    | ##################################### | 100%
# wcwidth-0.2.5        | 33 KB     | ##################################### | 100%
# pandocfilters-1.5.0  | 11 KB     | ##################################### | 100%
# ipython-7.28.0       | 1.1 MB    | ##################################### | 100%
# parso-0.8.2          | 68 KB     | ##################################### | 100%
# prompt-toolkit-3.0.2 | 248 KB    | ##################################### | 100%
# traittypes-0.2.1     | 10 KB     | ##################################### | 100%
# bleach-4.1.0         | 121 KB    | ##################################### | 100%
# pygments-2.10.0      | 760 KB    | ##################################### | 100%
# jupyter_client-7.0.6 | 87 KB     | ##################################### | 100%
# pickleshare-0.7.5    | 9 KB      | ##################################### | 100%
# pathlib-1.0.1        | 4 KB      | ##################################### | 100%
# pythreejs-2.3.0      | 2.6 MB    | ##################################### | 100%
# pyrsistent-0.17.3    | 88 KB     | ##################################### | 100%
# notebook-6.4.5       | 6.3 MB    | ##################################### | 100%
# terminado-0.12.1     | 27 KB     | ##################################### | 100%
# cytoolz-0.11.0       | 344 KB    | ##################################### | 100%
# jsonschema-4.1.2     | 54 KB     | ##################################### | 100%
# argon2-cffi-21.1.0   | 46 KB     | ##################################### | 100%
# async_generator-1.10 | 18 KB     | ##################################### | 100%
# entrypoints-0.3      | 8 KB      | ##################################### | 100%
# backports-1.0        | 4 KB      | ##################################### | 100%
# nbconvert-6.2.0      | 534 KB    | ##################################### | 100%
# decorator-5.1.0      | 11 KB     | ##################################### | 100%
# jupyterlab_pygments- | 8 KB      | ##################################### | 100%
# testpath-0.5.0       | 86 KB     | ##################################### | 100%
# jinja2-3.0.2         | 99 KB     | ##################################### | 100%
# scikit-image-0.17.2  | 10.3 MB   | ##################################### | 100%
# ipython_genutils-0.2 | 21 KB     | ##################################### | 100%
# nbclient-0.5.4       | 60 KB     | ##################################### | 100%
# pyzmq-22.2.1         | 421 KB    | ##################################### | 100%
# appnope-0.1.2        | 10 KB     | ##################################### | 100%
# toolz-0.11.1         | 46 KB     | ##################################### | 100%
# ipywebrtc-0.6.0      | 187 KB    | ##################################### | 100%
# defusedxml-0.7.1     | 23 KB     | ##################################### | 100%
# pexpect-4.8.0        | 47 KB     | ##################################### | 100%
# enum34-1.1.10        | 4 KB      | ##################################### | 100%
# zeromq-4.3.4         | 289 KB    | ##################################### | 100%
# mistune-0.8.4        | 54 KB     | ##################################### | 100%
# ipykernel-5.5.5      | 167 KB    | ##################################### | 100%
# ipydatawidgets-4.2.0 | 171 KB    | ##################################### | 100%
# libsodium-1.0.18     | 516 KB    | ##################################### | 100%
# jupyterlab_widgets-1 | 130 KB    | ##################################### | 100%
# prometheus_client-0. | 46 KB     | ##################################### | 100%
# locket-0.2.0         | 6 KB      | ##################################### | 100%
# imagecodecs-lite-201 | 171 KB    | ##################################### | 100%
# jupyter_core-4.8.1   | 78 KB     | ##################################### | 100%
# pywavelets-1.1.1     | 4.3 MB    | ##################################### | 100%
# bqplot-0.12.31       | 1.0 MB    | ##################################### | 100%
# markupsafe-2.0.1     | 21 KB     | ##################################### | 100%
# ipyvolume-0.6.0a8    | 1.2 MB    | ##################################### | 100%
# dask-core-2021.10.0  | 775 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: | Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK
#
# done

# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from math import sqrt
from mpl_toolkits.mplot3d import axes3d
import numpy as np
import json
with open('bodies.json') as f:
    data_bodies = json.load(f)

coords = data_bodies["coords"]
iters = data_bodies["iter"]
bodies = data_bodies["num"]
plt.rcParams["figure.figsize"] = (30,20)
fig = plt.figure()
ax = fig.add_subplot(1,1,1, projection='3d')
#coords = np.reshape(data_bodies["coords"], (data_bodies["iter"], data_bodies["num"], 3))
#print(coords)
colors = ['	black','silver',]
for i in [0,3]:
    x_body_coords = coords[i * 3 + 0 : : bodies * 3]
    y_body_coords = coords[i * 3 + 1 : : bodies * 3]
    z_body_coords = coords[i * 3 + 2 : : bodies * 3]
    ax.plot(list(map(float, x_body_coords)),list(map(float, y_body_coords)),list(map(float, z_body_coords)))

    #axes.plot([i for i in range(len(sq_vec))],list(map(float, sq_vec)),linestyle='solid', marker='o', markersize=4, label='|X-X0|')  
#ax.set_xlabel('X axis')
#ax.set_ylabel('Y axis')
#ax.set_zlabel('Z axis')

plt.savefig('anime2.png', dpi=300)
